# %% [markdown]
# # Importing useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Uploading data from local file directory

# %%
# from url 
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv'
# data = pd.read_csv(url)

# %%
data = pd.read_csv('energydata_complete.csv')
data.head(2)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2     RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.7900
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.7225
#
#       T3   RH_3    T4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.79  44.73  19.0  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  19.79  44.79  19.0  ...  17.066667  45.56  6.483333        733.6    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0   7.000000   63.000000        5.3  13.275433  13.275433
# 1   6.666667   59.166667        5.2  18.606195  18.606195
#
# [2 rows x 29 columns]

# %%
data.drop(['date', 'lights'], axis=1, inplace=True)
data.head(2)
# Out:
#    Appliances     T1       RH_1    T2     RH_2     T3   RH_3    T4       RH_4  \
# 0          60  19.89  47.596667  19.2  44.7900  19.79  44.73  19.0  45.566667
# 1          60  19.89  46.693333  19.2  44.7225  19.79  44.79  19.0  45.992500
#
#           T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  Windspeed  \
# 0  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0   7.000000
# 1  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0   6.666667
#
#    Visibility  Tdewpoint        rv1        rv2
# 0   63.000000        5.3  13.275433  13.275433
# 1   59.166667        5.2  18.606195  18.606195
#
# [2 rows x 27 columns]

# %%
# Importing neccesary packages

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
normalised_data = pd.DataFrame(MinMaxScaler().fit_transform(data), columns=data.columns)
df = normalised_data
df.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1  0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2  0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3  0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4  0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %% [markdown]
# # Question 12

# %%
X = df['T2'].values.reshape(-1, 1)
y = df['T6']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=42)
lr = LinearRegression()
lr.fit(X_train, y_train)
round(lr.score(X_test, y_test), 2)
# Out:
# 0.64

# %%
y_pred = lr.predict(X_test)
round(r2_score(y_test, y_pred), 2)
# Out:
# 0.64

# %% [markdown]
# # Question 13

# %%
X = df.drop('Appliances', axis=1)
y = df['Appliances']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=42)
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

# %%
round(mae, 2)
# Out:
# 0.05

# %% [markdown]
# # Question 14

# %%
rss = np.sum(np.square(y_test - y_pred))
round(rss, 2)
# Out:
# 45.35

# %% [markdown]
# # Question 15

# %%
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred))
round(rmse_lr, 3)
# Out:
# 0.088

# %% [markdown]
# # Question 16

# %%
r2 = r2_score(y_test, y_pred)
round(r2, 2)
# Out:
# 0.15

# %% [markdown]
# # Question 17

# %%
X = df.drop('Appliances', axis=1)
y = df['Appliances']
X.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
LinearReg = pd.DataFrame(lr.coef_, index=X.columns, columns=['LinearReg weights'])
LinearReg.sort_values(by='LinearReg weights').drop(['rv1', 'rv2'], axis=0)
# Out:
#              LinearReg weights
# RH_2                 -0.456701
# T_out                -0.321868
# T2                   -0.236185
# T9                   -0.189932
# RH_8                 -0.157597
# RH_out               -0.077681
# RH_7                 -0.044613
# RH_9                 -0.039795
# T5                   -0.015658
# T1                   -0.003281
# Press_mm_hg           0.006839
# T7                    0.010302
# Visibility            0.012308
# RH_5                  0.016009
# RH_4                  0.026388
# T4                    0.028984
# Windspeed             0.029183
# RH_6                  0.038049
# RH_3                  0.096045
# T8                    0.102000
# Tdewpoint             0.117764
# T6                    0.236424
# T3                    0.290633
# RH_1                  0.553546

# %%
X = df.drop('Appliances', axis=1)
y = df['Appliances']
X.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %% [markdown]
# # Question 13

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=42)
rr = Ridge(alpha=0.4)
rr.fit(X_train, y_train)

y = rr.predict(X_test)
rmse_rr = np.sqrt(mean_squared_error(y_test, y_pred))
round(rmse_rr, 3)
# Out:
# 0.088

# %%
assert round(rmse_rr, 3) == round(rmse_lr, 3)

# %%
X = df.drop('Appliances', axis=1)
y = df['Appliances']

# %%
X.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=42)

ls = Lasso(alpha=0.001)
ls.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %% [markdown]
# # Question 19

# %%
LassoReg = pd.DataFrame(ls.coef_, index=X.columns, columns=['LassoReg weights'])
print(f"The number of non zero weights are: {len(LassoReg[LassoReg['LassoReg weights']!=0])}")
LassoReg[LassoReg['LassoReg weights']!=0]
# Out:
# The number of non zero weights are: 4
#            LassoReg weights
# RH_1               0.017880
# RH_8              -0.000110
# RH_out            -0.049557
# Windspeed          0.002912

# %% [markdown]
# # Question 20

# %%
y = ls.predict(X_test)
rmse_ls = np.sqrt(mean_squared_error(y_test, y_pred))
round(rmse_ls, 3)
# Out:
# 0.088
